# %% [markdown]
# Descargarse paquete desde github
# https://github.com/migueltellogomez-glitch/proyectopython.git

# %%
#!git clone https://github.com/migueltellogomez-glitch/proyectopython.git
import sys
import os

ruta_libreria = '/content/proyectopython/cei_template1/cei_template'

if ruta_libreria not in sys.path:
    sys.path.append(ruta_libreria)

# %%
import os
import sys
from cei_template.Fachadataller import Fachadataller

sys.path.append(os.path.abspath("cei_template"))

def main():

    taller = Fachadataller()
    print(taller.get_vehiculos())
    for i, grafico in enumerate(taller.get_lista_graficos()):
        grafico.show()
    print(taller.realizar_mantenimiento("ABC123"))
    print(taller.realizar_mantenimiento("BAB654"))
    taller.agregar_vehiculo(taller.vehiculo_factory.crear_vehiculo("Camion Basura", {
        "matricula": "NEW999",
        "estado_mantenimiento": "Bueno",
        "kilometraje": 5000,
        "capacidad_toneladas": 10,
        "tipo_compactador": "Compactador de tornillo"
    }))
    taller.actualizar_base_de_datos()
    print([vehiculo.obtener_info() for vehiculo in taller.get_vehiculos()])
    taller.reparar_vehiculo("NEW999")
    print(taller.get_vehiculo_por_matricula("NEW999").obtener_info())





if __name__ == '__main__':
    main()
# Out:
# Tipo de vehículo desconocido en la base de datos:Furgoneta
# [<cei_template.CamionBasura.CamionBasura object at 0x7c19042e9490>, <cei_template.Barredora.Barredora object at 0x7c19042441a0>, <cei_template.CamionBasura.CamionBasura object at 0x7c1904367350>, <cei_template.CamionBasura.CamionBasura object at 0x7c1904227590>, <cei_template.CamionBasura.CamionBasura object at 0x7c190403cda0>]
# [Camión Basura] Mantenimiento preventivo del compactador Compactador de tornillo en vehículo ABC123.
# [Barredora] Limpiando 4 cepillos y revisando bomba de agua en vehículo BAB654.
# [{'matricula': 'ABC123', 'estado_mantenimiento': 'Pendiente', 'kilometraje': 150200, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': 'Cambio de aceite', 'coste_reparacion': 100, 'capacidad_toneladas': 12, 'tipo_compactador': 'Compactador de tornillo'}, {'matricula': 'BAB654', 'estado_mantenimiento': 'En curso', 'kilometraje': 12000, 'tipo_vehiculo': 'Barredora', 'descripcion_averia': 'Cambio de aceite', 'coste_reparacion': 111, 'capacidad_agua_litros': 5000, 'numero_cepillos': 4}, {'matricula': 'IJH456', 'estado_mantenimiento': 'Pendiente', 'kilometraje': 210000, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': 'Rueda pinchada, Cambio de aceite', 'coste_reparacion': 112, 'capacidad_toneladas': 12, 'tipo_compactador': 'Compactador de tornillo'}, {'matricula': 'XXX069', 'estado_mantenimiento': 'En curso', 'kilometraje': 45000, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': 'Cristal roto', 'coste_reparacion': 1223, 'capacidad_toneladas': 12, 'tipo_compactador': 'Compactador de tornillo'}, {'matricula': 'NNN333', 'estado_mantenimiento': 'Bueno', 'kilometraje': 5000, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': 'Cristal dañado', 'coste_reparacion': 1334, 'capacidad_toneladas': 12, 'tipo_compactador': 'Compactador de tornillo'}, {'matricula': 'NEW999', 'estado_mantenimiento': 'Bueno', 'kilometraje': 5000, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': '', 'coste_reparacion': 0.0, 'capacidad_toneladas': 10, 'tipo_compactador': 'Compactador de tornillo'}]
# {'matricula': 'NEW999', 'estado_mantenimiento': 'Reparado', 'kilometraje': 5000, 'tipo_vehiculo': 'Camion Basura', 'descripcion_averia': '', 'coste_reparacion': 0.0, 'capacidad_toneladas': 10, 'tipo_compactador': 'Compactador de tornillo'}
